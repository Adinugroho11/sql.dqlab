# %% [markdown]
# # Numeric: Integer & Float
# Pengenalan tipe data numerik

# %%
x = 25

# %%
print(x)
# Out:
# 25

# %%
print(x + 5)
# Out:
# 30

# %%
type
# Out:
# type

# %%
a = 3.5

# %%
print(a)
# Out:
# 3.5

# %%
type(a)
# Out:
# float

# %% [markdown]
# # Mathematical Process

# %%
# penjumlahan
#    25  3.5
print(x + a)
# Out:
# 28.5

# %%
# pengurangan
print(x - a)
# Out:
# 21.5

# %%
# perkalian
print(x * a)
# Out:
# 87.5

# %%
# pembagian
print(x / a)
# Out:
# 7.142857142857143

# %%
# pembagian (pembulatan)
print(x // a)
# Out:
# 7.0

# %%
# pangkat
#    25 ^  3.5
print(x ** a)
# Out:
# 78125.0

# %%
# pangkat
print(x ** 2)
# Out:
# 625

# %%
# akar 2
print(x ** (1/2))
# Out:
# 5.0

# %%
print(x ** 0.5)
# Out:
# 5.0

# %%
import math
math.ceil(7/4)
# Out:
# 2

# %%
math.floor(7/4)
# Out:
# 1

# %%
print(7/4)
# Out:
# 1.75

# %%
round(7/4)
# Out:
# 2

# %%
# modulo / modulus / sisa pembagian
print(25 % 2)
# Out:
# 1

# %% [markdown]
# # Boolean

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# # Operasi Perbandingan

# %%
# > lebih dari
# < kurang dari
# >= lebih dari atau sama dengan
# <= kurang dari atau sama dengan
# == sama dengan
# != tidak sama dengan
# operasi perbandingan akan menghasilkan True atau False

# %%
a = 4
b = 5

# %%
hasil = a > b

# %%
print(hasil)
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a < b
# Out:
# True

# %% [markdown]
# # String

# %%
message = "Hi, my name is Adi"
print(message)
# Out:
# Hi, my name is Adi

# %%
type(message)
# Out:
# str

# %%
message2 = 'Hi, my name is Adi'
print(message2)
# Out:
# Hi, my name is Adi

# %%
type(message2)
# Out:
# str

# %%
contoh_txt = "I'm Adi"
print(contoh_txt)
# Out:
# I'm Adi

# %%
type(contoh_txt)
# Out:
# str

# %%
# Gunakan " " di luar
contoh_txt2 = "I'm Adi"
print(contoh_txt2)
# Out:
# I'm Adi

# %%
contoh_txt3 = 'I\'m Adi'
print(contoh_txt3)
# Out:
# I'm Adi

# %%
contoh_txt4 = 'Hi, my name is Adi "The Data Scientist"'
print(contoh_txt4)
# Out:
# Hi, my name is Adi "The Data Scientist"

# %%
contoh_txt5 = '''Hi, my name is Adi
I'm a Data Scientist'''
print(contoh_txt5)
# Out:
# Hi, my name is Adi
# I'm a Data Scientist

# %%
# Gunakan 3 tanda kutip
contoh_txt6 = """Hi, my name is Adi
I am a Data Scientist"""

print(contoh_txt6)
# Out:
# Hi, my name is Adi
# I am a Data Scientist

# %%
contoh_txt7 = "Hi, my name is Adi\
I am a Data Scientist"
print(contoh_txt7)
# Out:
# Hi, my name is AdiI am a Data Scientist

# %% [markdown]
# ## add new string

# %%
sentence1 = "Last week I went to Bangkok."
sentence2 = "I liked to shop there."

# %%
combine1 = sentence1 + sentence2
print(combine1)
# Out:
# Last week I went to Bangkok.I liked to shop there.

# %%
combine2 = sentence1 + " " + sentence2
print(combine2)
# Out:
# Last week I went to Bangkok. I liked to shop there.

# %%
contoh_txt = 'im"ridho'
print(contoh_txt)
# Out:
# im"ridho

# %%
sentence3 = "I went to Bangkok using airplane."
combine3 = combine2 + " " + sentence3
print(combine3)
# Out:
# Last week I went to Bangkok. I liked to shop there. I went to Bangkok using airplane.

# %%
sentence3 = "I went to Bangkok using airplane."
combine3 = combine2 + "\n" + sentence3
print(combine3)
# Out:
# Last week I went to Bangkok. I liked to shop there.
# I went to Bangkok using airplane.

# %%
combine4 = f"{sentence1} {sentence2} {sentence3} \n The tickets cost me IDR {900000*3}"
print(combine4)
# Out:
# Last week I went to Bangkok. I liked to shop there. I went to Bangkok using airplane.
#  The tickets cost me IDR 2700000

# %% [markdown]
# # String Methods

# %%
kalimat = "Saya suka bepergian dengan keluarga"

# %%
kalimat.upper()
# Out:
# 'SAYA SUKA BEPERGIAN DENGAN KELUARGA'

# %%
print(kalimat)
# Out:
# Saya suka bepergian dengan keluarga

# %%
kalimat = kalimat.upper()
print(kalimat)
# Out:
# SAYA SUKA BEPERGIAN DENGAN KELUARGA

# %%
print(kalimat.upper())
# Out:
# SAYA SUKA BEPERGIAN DENGAN KELUARGA

# %%
kalimat.lower()
# Out:
# 'saya suka bepergian dengan keluarga'

# %%
kalimat.swapcase()
# Out:
# 'saya suka bepergian dengan keluarga'

# %%
4 + 2
# Out:
# 6

# %%
kalimat.title()
# Out:
# 'Saya Suka Bepergian Dengan Keluarga'

# %%
kalimat.isalpha()
# Out:
# False

# %%
kalimat.isalnum()
# Out:
# False

# %%
"sayasukabepergiandengankeluarga".isalpha()
# Out:
# True

# %%
"Adi123".isalnum()
# Out:
# True

# %%
kalimat.count("s")
# Out:
# 0

# %%
kalimat.replace('a', 'i')
# Out:
# 'SAYA SUKA BEPERGIAN DENGAN KELUARGA'

# %%
kalimat.replace("keluarga", "teman")
# Out:
# 'SAYA SUKA BEPERGIAN DENGAN KELUARGA'

# %% [markdown]
# ## String Indexing

# %%
kalimat[0]
# Out:
# 'S'

# %%
# cara pertama
kalimat[15]
# Out:
# 'G'

# %%
kalimat = "I am a Data Scientist"

# Cari huruf 'a' (ini akan berhasil)
print(kalimat[kalimat.index('a')])
# Out:
# a

# %%
kalimat.index('a')
# Out:
# 2

# %%
kalimat[0:3]
# Out:
# 'I a'

# %%
kalimat.split()
# Out:
# ['I', 'am', 'a', 'Data', 'Scientist']

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# contoh bikin kolom baru
df["name"] = "Adi Nugroho"
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
name = df['name']
name
# Out:
# 0        Adi Nugroho
# 1        Adi Nugroho
# 2        Adi Nugroho
# 3        Adi Nugroho
# 4        Adi Nugroho
#             ...
# 16995    Adi Nugroho
# 16996    Adi Nugroho
# 16997    Adi Nugroho
# 16998    Adi Nugroho
# 16999    Adi Nugroho
# Name: name, Length: 17000, dtype: object

# %%
df['First_Name'] = df['name'].str[0:5]
df['Last_Name'] = df['name'].str[6:10]
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value         name  \
# 0      1015.0       472.0         1.4936             66900.0  Adi Nugroho
# 1      1129.0       463.0         1.8200             80100.0  Adi Nugroho
# 2       333.0       117.0         1.6509             85700.0  Adi Nugroho
# 3       515.0       226.0         3.1917             73400.0  Adi Nugroho
# 4       624.0       262.0         1.9250             65500.0  Adi Nugroho
#
#   First_Name Last_Name
# 0      Adi N      groh
# 1      Adi N      groh
# ...

# %%
# !jupyter nbconvert --ClearMetadataPreprocessor.enabled=True \
  --to notebook \
  --output cleared_notebook.ipynb \
"/content/sample_data/New_Pilot_Class_SQL___Number_DateFormat&_SubQuery.ipynb"
